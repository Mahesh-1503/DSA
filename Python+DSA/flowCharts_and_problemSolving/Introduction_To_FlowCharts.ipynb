# %% [markdown]
# ### Basics of problem solving
# #### Flow Chart
# 1. A flow chart is a graphical representation of the steps in a process.
# 2. It uses symbols and arrows to show the sequence of steps needed to complete a task.
# 3. Flow charts are useful in visualizing how to solve a problem and make the process easier to understand.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Flowchart to display maximum of 2 numbers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Flow chart to add 2 numbers

# %% [markdown]
# ![image.png](attachment:image.png)
